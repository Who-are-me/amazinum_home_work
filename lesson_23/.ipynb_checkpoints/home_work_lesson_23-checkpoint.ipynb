# %% [markdown]
# ### lesson \#23 by Storchak Vasyl

# %%
import platform
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data & prep.

# %%
# EDA

# %%
#########################################################################################################################################

# %%
# sarimax

# %%
# sarimax metric & visualize

# %%
#########################################################################################################################################

# %%
# prophet

# %%
# prophet metric & visualize

# %%
#########################################################################################################################################

# %%
# time lagged regression

# %%
# time lagged regression metric & visualize

# %%
#########################################################################################################################################

# %%
# chronos bolt

# %%
# chronos bolt metric & visualize
