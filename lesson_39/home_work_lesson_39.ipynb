# %% [markdown]
# ### home work of lesson 39 by Vasyl Storchak

# %% [markdown]
# ## 1-4 setup python and dep.

# %% [markdown]
# ![title](i1.png)

# %% [markdown]
# ![title](i2.png)

# %% [markdown]
# ![title](i3.png)

# %% [markdown]
# ![title](i4.png)

# %% [markdown]
# ## 5 pre-commit

# %% [markdown]
# ![title](i5.png)

# %% [markdown]
# ## 6 setup ollama

# %% [markdown]
# ![title](i6.png)

# %% [markdown]
# # PART 2 semantic search

# %% [raw]
# # як на мене то допустима помилка так як поставив gpu по можливості, не примусово
# FAILED tests/test_text_vectorizer.py::TestTextVectorizer::test_init_success - AssertionError: expected call not found.
# FAILED tests/test_text_vectorizer.py::TestTextVectorizer::test_device_selection - AssertionError: assert 'cuda' == 'cpu'

# %% [markdown]
# ![title](i7.png)

# %% [markdown]
# ![title](8.png)

# %% [markdown]
# ### доступ до / я не дам! або хтось не правильно написав тест

# %% [markdown]
# ![title](9.png)

# %%
пройшов пасс лише якщо створив в руті папку з доступом

# %% [markdown]
# # PART 3 summarization with llm

# %% [markdown]
# ![title](10.png)

# %% [raw]
# I test with model qwen3:4b (but i dont disable verbose)

# %% [markdown]
# ![title](11.png)

# %% [markdown]
# # PART 4 api

# %% [markdown]
# ![title](12.png)

# %% [markdown]
# # PART 5 run test

# %% [markdown]
# ![title](15.png)

# %% [markdown]
# ![title](14.png)

# %% [markdown]
# ![title](13.png)
